# %%
path = "Life_Expectancy_Data.csv"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(path)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
life_exp = df[["Country", "Year", "Life expectancy "]]
df.columns
life_exp
# Out:
#           Country  Year  Life expectancy
# 0     Afghanistan  2015              65.0
# 1     Afghanistan  2014              59.9
# 2     Afghanistan  2013              59.9
# 3     Afghanistan  2012              59.5
# 4     Afghanistan  2011              59.2
# ...           ...   ...               ...
# 2933     Zimbabwe  2004              44.3
# 2934     Zimbabwe  2003              44.5
# 2935     Zimbabwe  2002              44.8
# 2936     Zimbabwe  2001              45.3
# 2937     Zimbabwe  2000              46.0
#
# [2938 rows x 3 columns]

# %%
import seaborn as sns

sns.pairplot(life_exp)

# %%
records_country = life_exp["Country"].value_counts()==1
records_country[records_country==True]
# Countries with only one record
# Out:
# Dominica                 True
# Niue                     True
# Nauru                    True
# Saint Kitts and Nevis    True
# Monaco                   True
# Palau                    True
# San Marino               True
# Marshall Islands         True
# Cook Islands             True
# Tuvalu                   True
# Name: Country, dtype: bool

# %%
# Dropping them
life_exp = life_exp[life_exp.groupby('Country').Country.transform(len) > 1]
(life_exp["Country"].value_counts()==1).any()
# Out:
# False

# %%
# Attempt: selecting 5 countries randomly
# countries = list(pd.unique(life_exp.Country))
# for i in range(5):
#     j = np.random.randint(0, 183)
#     country = life_exp["Country"].iloc[j]
#     globals()[f"life_exp_{country}"] = life_exp[life_exp["Country"].iloc[i]]

# %%
life_exp.groupby(by="Country").mean()
# Out:
#                                       Year  Life expectancy
# Country
# Afghanistan                         2007.5          58.19375
# Albania                             2007.5          75.15625
# Algeria                             2007.5          73.61875
# Angola                              2007.5          49.01875
# Antigua and Barbuda                 2007.5          75.05625
# ...                                    ...               ...
# Venezuela (Bolivarian Republic of)  2007.5          73.38750
# Viet Nam                            2007.5          74.77500
# Yemen                               2007.5          63.86250
# Zambia                              2007.5          53.90625
# Zimbabwe                            2007.5          50.48750
#
# [183 rows x 2 columns]
